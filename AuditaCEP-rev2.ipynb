# %%
#pip install python-cep

import buscacep
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

arquivo = "/media/vagner/Seagate Expansion Drive/500Gb/DiskExternoVagner/Cursos/CientistaDados/Modulo_4/DW-OSM-RMSP/sample.osm"
#arquivo = r'F:\500Gb\DiskExternoVagner\Cursos\CientistaDados\Modulo_4\DW-OSM-RMSP\sample.osm'

osm_file = open(arquivo, "r")

def audit():
    """     Realiza análise baseada no evento "tag de ínicio"; quando este ocorre o elemento em questão é 
    identificado e se for do tipo "way", o método "iter" é chamado; este método realiza uma iteração de todas as 
    subtags (tags aninhadas) do tipo "tag".
    """
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_postcode(tag):
                    #audit_postcode(tag.attrib['v'])
                    valida_cep(tag.attrib['v'])

def is_postcode(elem):
    """     Verifica se o tag é um atributo de (addr:postcode). Retorna um Boolean (True se atributo
    de CEP)           
    """
    return (elem.attrib['k'] == "addr:postcode")

def audit_postcode(postcode):
    """     Utiliza expressão regular para verificar o ínicio do campo "addr:street" identificando assim o Tipo de 
    Via (Rua, Alamenda, etc)
    """
    postcode_re = re.match(r'^\d{5}-\d{3}$', postcode)
    #postcode_re = re.match(r'^\d{5}-?\d{3}$', postcode)  Considerando o "-" opcional
    #print postcode_re
    if postcode_re== None:
        cep_novo = re.split(r'^\d{3}', postcode)
        print postcode, "=>", "com problema" 
        print cep_novo, "=>", "novo" 
    

def valida_cep (postcode):
    postcode_re = re.sub(r'\D',"" ,postcode)
    #res = buscacep.busca_cep_correios(postcode_re)
    aux=True
    while aux:
        try:
            res=buscacep.busca_cep_correios_as_dict(postcode_re)
            print postcode, postcode_re
            pprint.pprint(res)
            break
        except AttributeError:
            print "CEP", postcode, "Nao existe"
            aux=False
    
    
    #return res
    
    
if __name__ == '__main__':
    audit()
    osm_file.close()
# Out:
# 04094-050 04094050
# {'bairro': u'Parque Ibirapuera',
#  'cep': u'04094-050',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Pedro \xc1lvares Cabral'}
# 08710-280 08710280
# {'bairro': u'Centro',
#  'cep': u'08710-280',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Rua Alfredo Cardoso'}
# 08773-300 08773300
# {'bairro': u'Vila Mogilar',
#  'cep': u'08773-300',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Rua Casarejos'}
# 08770-060 08770060
# {'bairro': u'Vila Industrial',
#  'cep': u'08770-060',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Rua Afif Nacif Jafet'}
# 08770-020 08770020
# {'bairro': u'Vila Industrial',
#  'cep': u'08770-020',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Rua Doutor Rubi\xe3o J\xfanior'}
# 08780-260 08780260
# {'bairro': u'Parque Monte L\xedbano',
#  'cep': u'08780-260',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Rua Jo\xe3o Cardoso Pereira'}
# 03166-000 03166000
# {'bairro': u'Mooca',
#  'cep': u'03166-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Taquari - at\xe9 799/800'}
# 04795-100 04795100
# {'bairro': u'Vila Almeida',
#  'cep': u'04795-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida das Na\xe7\xf5es Unidas - de 17281 ao fim - lado \xedmpar'}
# 04795-100 04795100
# {'bairro': u'Vila Almeida',
#  'cep': u'04795-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida das Na\xe7\xf5es Unidas - de 17281 ao fim - lado \xedmpar'}
# 04734-003 04734003
# {'bairro': u'Santo Amaro',
#  'cep': u'04734-003',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1564 a 2100 - lado par'}
# 04734-003 04734003
# {'bairro': u'Santo Amaro',
#  'cep': u'04734-003',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1564 a 2100 - lado par'}
# 04734-003 04734003
# {'bairro': u'Santo Amaro',
#  'cep': u'04734-003',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1564 a 2100 - lado par'}
# 04474-340 04474340
# {'bairro': u'Balne\xe1rio S\xe3o Francisco',
#  'cep': u'04474-340',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Estrada do Alvarenga - de 2701/2702 ao fim'}
# 04027-000 04027000
# {'bairro': u'Vila Clementino',
#  'cep': u'04027-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Professor Ascendino Reis'}
# 04005-005 04005005
# {'bairro': u'Para\xedso',
#  'cep': u'04005-005',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Ab\xedlio Soares - de 1321/1322 ao fim'}
# 04733-300 04733300
# {'bairro': u'Santo Amaro',
#  'cep': u'04733-300',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1587 a 1937 - lado \xedmpar'}
# 04734-003 04734003
# {'bairro': u'Santo Amaro',
#  'cep': u'04734-003',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1564 a 2100 - lado par'}
# 04733-300 04733300
# {'bairro': u'Santo Amaro',
#  'cep': u'04733-300',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1587 a 1937 - lado \xedmpar'}
# 04737-030 04737030
# {'bairro': u'Santo Amaro',
#  'cep': u'04737-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Graham Bell'}
# 04738-000 04738000
# {'bairro': u'Santo Amaro',
#  'cep': u'04738-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Marechal Deodoro - at\xe9 671/672'}
# 04701-100 04701100
# {'bairro': u'Santo Amaro',
#  'cep': u'04701-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Santo Amaro - de 6163 a 6781 - lado \xedmpar'}
# 04029-100 04029100
# {'bairro': u'Indian\xf3polis',
#  'cep': u'04029-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Ibirapuera - de 1733 a 2305 - lado \xedmpar'}
# 04508-030 04508030
# {'bairro': u'Vila Nova Concei\xe7\xe3o',
#  'cep': u'04508-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Jo\xe3o Louren\xe7o - at\xe9 639/640'}
# 04734-003 04734003
# {'bairro': u'Santo Amaro',
#  'cep': u'04734-003',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1564 a 2100 - lado par'}
# 04734-003 04734003
# {'bairro': u'Santo Amaro',
#  'cep': u'04734-003',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1564 a 2100 - lado par'}
# 04734-003 04734003
# {'bairro': u'Santo Amaro',
#  'cep': u'04734-003',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1564 a 2100 - lado par'}
# 04717-000 04717000
# {'bairro': u'Ch\xe1cara Santo Ant\xf4nio (Zona Sul)',
#  'cep': u'04717-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Alexandre Dumas - at\xe9 659/660'}
# 04733-400 04733400
# {'bairro': u'Santo Amaro',
#  'cep': u'04733-400',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Adolfo Pinheiro - de 1939 ao fim - lado \xedmpar'}
# 09895-400 09895400
# {'bairro': u'Planalto',
#  'cep': u'09895-400',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Dom Jaime de Barros C\xe2mara'}
# 09895-900 09895900
# {'bairro': u'Planalto',
#  'cep': u'09895-900',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Max Mangels S\xeanior, 777  Mangel S\xe3o Bernardo S.A.'}
# 02960-020 02960020
# {'bairro': u'Moinho Velho',
#  'cep': u'02960-020',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Manuel Madruga'}
# 05593-090 05593090
# {'bairro': u'Jardim Bonfiglioli',
#  'cep': u'05593-090',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Azem Abdala Azem'}
# 09210-580 09210580
# {'bairro': u'Jardim Alzira Franco',
#  'cep': u'09290-340',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Avenida dos Estados'}
# 09190-210 09190210
# {'bairro': u'Para\xedso',
#  'cep': u'09190-210',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Avenida Pereira Barreto - lado par'}
# 04169-000 04169000
# {'bairro': u'Vila Moraes',
#  'cep': u'04169-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida do Cursino - de 3891/3892 ao fim'}
# 04206-000 04206000
# {'bairro': u'Ipiranga',
#  'cep': u'04206-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Agostinho Gomes - at\xe9 1829/1830'}
# 04204-030 04204030
# {'bairro': u'Ipiranga',
#  'cep': u'04204-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua da Constituinte'}
# 04204-030 04204030
# {'bairro': u'Ipiranga',
#  'cep': u'04204-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua da Constituinte'}
# 04205-001 04205001
# {'bairro': u'Ipiranga',
#  'cep': u'04205-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Cipriano Barata - de 1201/1202 a 2229/2230'}
# CEP 09771-000 Nao existe
# 09710-000 09710000
# {'bairro': u'Centro',
#  'cep': u'09710-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Marechal Deodoro - at\xe9 0820 - lado par'}
# 09720-971 09720971
# {'bairro': u'Centro',
#  'cep': u'09720-971',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Brigadeiro Faria Lima, 845  AC S\xe3o Bernardo do Campo'}
# 09720-010 09720010
# {'bairro': u'Centro',
#  'cep': u'09720-010',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Brigadeiro Faria Lima - lado \xedmpar'}
# 09760-000 09760000
# {'bairro': u'Baeta Neves',
#  'cep': u'09760-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua dos Vianas - at\xe9 719/720'}
# 04280-010 04280010
# {'bairro': u'Vila Nair',
#  'cep': u'04280-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Francisco Peres'}
# 07190-012 07190012
# {'bairro': u'Parque Cecap',
#  'cep': u'07190-012',
#  'localidade': u'Guarulhos/SP',
#  'logradouro': u'Alameda dos L\xedrios'}
# 05424-150 05424150
# {'bairro': u'Pinheiros',
#  'cep': u'05424-150',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Pais Leme - lado \xedmpar'}
# 09210-580 09210580
# {'bairro': u'Jardim Alzira Franco',
#  'cep': u'09290-340',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Avenida dos Estados'}
# 06719500 06719500
# {'bairro': u'Jardim \xcdsis',
#  'cep': u'06719-500',
#  'localidade': u'Cotia/SP',
#  'logradouro': u'Estrada Morro Grande - de 1001/1002 ao fim'}
# 03147-100 03147100
# {'bairro': u'Vila Bela',
#  'cep': u'03147-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Paramu'}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 09691000 09691000
# {'bairro': u'Paulic\xe9ia',
#  'cep': u'09691-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua J\xfalio de Mesquita - at\xe9 699/700'}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 06717-100 06717100
# {'bairro': u'Parque Bahia',
#  'cep': u'06717-100',
#  'localidade': u'Cotia/SP',
#  'logradouro': u'Avenida Professor Manoel Jos\xe9 Pedroso'}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 07600-000 07600000
# {'bairro': u'',
#  'cep': u'07600-000',
#  'localidade': u'Mairipor\xe3/SP',
#  'logradouro': u''}
# 04051-000 04051000
# {'bairro': u'Mirand\xf3polis',
#  'cep': u'04051-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua das Hort\xeansias'}
# 09686-000 09686000
# {'bairro': u'Paulic\xe9ia',
#  'cep': u'09686-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Martins'}
# 04205-001 04205001
# {'bairro': u'Ipiranga',
#  'cep': u'04205-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Cipriano Barata - de 1201/1202 a 2229/2230'}
# 04206-001 04206001
# {'bairro': u'Ipiranga',
#  'cep': u'04206-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Agostinho Gomes - de 1831/1832 a 3009/3010'}
# 04205-002 04205002
# {'bairro': u'Ipiranga',
#  'cep': u'04205-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Cipriano Barata - de 2231/2232 ao fim'}
# 04206-001 04206001
# {'bairro': u'Ipiranga',
#  'cep': u'04206-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Agostinho Gomes - de 1831/1832 a 3009/3010'}
# 04205-002 04205002
# {'bairro': u'Ipiranga',
#  'cep': u'04205-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Cipriano Barata - de 2231/2232 ao fim'}
# 04205-002 04205002
# {'bairro': u'Ipiranga',
#  'cep': u'04205-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Cipriano Barata - de 2231/2232 ao fim'}
# 04218-000 04218000
# {'bairro': u'Ipiranga',
#  'cep': u'04218-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Comandante Taylor'}
# 04206-001 04206001
# {'bairro': u'Ipiranga',
#  'cep': u'04206-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Agostinho Gomes - de 1831/1832 a 3009/3010'}
# 09890-002 09890002
# {'bairro': u'Planalto',
#  'cep': u'09890-002',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida \xc1lvaro Guimar\xe3es - de 0493/494 a 681/0682'}
# 04201-090 04201090
# {'bairro': u'Ipiranga',
#  'cep': u'04201-090',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Hip\xf3lito Soares'}
# 04202-030 04202030
# {'bairro': u'Ipiranga',
#  'cep': u'04202-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Bento Vieira'}
# 04201-050 04201050
# {'bairro': u'Ipiranga',
#  'cep': u'04201-050',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua C\xf4nego Janu\xe1rio'}
# 04201-090 04201090
# {'bairro': u'Ipiranga',
#  'cep': u'04201-090',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Hip\xf3lito Soares'}
# 04206-000 04206000
# {'bairro': u'Ipiranga',
#  'cep': u'04206-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Agostinho Gomes - at\xe9 1829/1830'}
# 04202-001 04202001
# {'bairro': u'Ipiranga',
#  'cep': u'04202-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua dos Sorocabanos - de 431/432 ao fim'}
# 18150-000 18150000
# {'bairro': u'',
#  'cep': u'18150-000',
#  'localidade': u'Ibi\xfana/SP',
#  'logradouro': u''}
# CEP 09898-003 Nao existe
# 09810-250 09810250
# {'bairro': u'Assun\xe7\xe3o',
#  'cep': u'09810-250',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Jo\xe3o Firmino - at\xe9 1220 - lado par'}
# 09750-360 09750360
# {'bairro': u'Jardim do Mar',
#  'cep': u'09750-360',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Tasman'}
# 09950-000 09950000
# {'bairro': u'Vila Nogueira',
#  'cep': u'09950-000',
#  'localidade': u'Diadema/SP',
#  'logradouro': u'Avenida Piraporinha'}
# 09830-110 09830110
# {'bairro': u'Rio Grande',
#  'cep': u'09830-110',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Araguaia'}
# 07033-180 07033180
# {'bairro': u'Jardim Munhoz',
#  'cep': u'07033-180',
#  'localidade': u'Guarulhos/SP',
#  'logradouro': u'Rua Ant\xf4nio Bonito'}
# 09726-253 09726253
# {'bairro': u'Jardim do Mar',
#  'cep': u'09726-253',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Kennedy - de 742 ao fim - lado par'}
# 09861-000 09861000
# {'bairro': u'Assun\xe7\xe3o',
#  'cep': u'09861-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Jos\xe9 Odorizzi - de 1091/1092 a 1629/1630'}
# 09861-630 09861630
# {'bairro': u'Assun\xe7\xe3o',
#  'cep': u'09861-630',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Francisco Visentainer (Vl S C\xe1ssia)'}
# 09726-253 09726253
# {'bairro': u'Jardim do Mar',
#  'cep': u'09726-253',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Kennedy - de 742 ao fim - lado par'}
# 01452-002 01452002
# {'bairro': u'Jardim Paulistano',
#  'cep': u'01452-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Brigadeiro Faria Lima - de 1027 a 1501 - lado \xedmpar'}
# 09715-090 09715090
# {'bairro': u'Centro',
#  'cep': u'09715-090',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Silva Jardim'}
# 09720-120 09720120
# {'bairro': u'Centro',
#  'cep': u'09720-120',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Marechal Rondon'}
# 05350-000 05350000
# {'bairro': u'Rio Pequeno',
#  'cep': u'05350-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Escola Polit\xe9cnica'}
# 01421-000 01421000
# {'bairro': u'Jardim Paulista',
#  'cep': u'01421-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Alameda Itu - at\xe9 738 - lado par'}
# 09581-420 09581420
# {'bairro': u'Jardim S\xe3o Caetano',
#  'cep': u'09581-420',
#  'localidade': u'S\xe3o Caetano do Sul/SP',
#  'logradouro': u'Rua Bell Aliance'}
# 09606-000 09606000
# {'bairro': u'Anchieta',
#  'cep': u'09606-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Vinte e Tr\xeas de Maio'}
# 08451-000 08451000
# {'bairro': u'Guaianazes',
#  'cep': u'08451-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Estrada do Lageado Velho - at\xe9 568 - lado par'}
# 08441-000 08441000
# {'bairro': u'Jardim Robru',
#  'cep': u'08441-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Doutor Jos\xe9 Gravonski - at\xe9 588/589'}
# 04922-100 04922100
# {'bairro': u'Ch\xe1cara Vista Alegre',
#  'cep': u'04922-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Itupu'}
# 09725-570 09725570
# {'bairro': u'Jardim Olavo Bilac',
#  'cep': u'09725-570',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Olavo Bilac'}
# 05587-190 05587190
# {'bairro': u'Jardim Rizzo',
#  'cep': u'05587-190',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Concei\xe7\xe3o Russomano Pugliese'}
# 03345-001 03345001
# {'bairro': u'Vila Regente Feij\xf3',
#  'cep': u'03345-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Sapopemba - at\xe9 4601 - lado \xedmpar'}
# 04149-080 04149080
# {'bairro': u'Jardim da Sa\xfade',
#  'cep': u'04149-080',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Filipe Cardoso'}
# 05315030 05315030
# {'bairro': u'Vila Leopoldina',
#  'cep': u'05315-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Nagel'}
# 09710-000 09710000
# {'bairro': u'Centro',
#  'cep': u'09710-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Marechal Deodoro - at\xe9 0820 - lado par'}
# 09810-800 09810800
# {'bairro': u'Assun\xe7\xe3o',
#  'cep': u'09810-800',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua L\xfacia Zincaglia'}
# 02220-001 02220001
# {'bairro': u'Vila Medeiros',
#  'cep': u'02220-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Itamonte - de 0425/426 a 1149/1150'}
# 09751-000 09751000
# {'bairro': u'Baeta Neves',
#  'cep': u'09751-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Pereira Barreto'}
# 09130-410 09130410
# {'bairro': u'Vila Tibiri\xe7\xe1',
#  'cep': u'09130-410',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Avenida Dom Pedro I - de 2101 a 3399 - lado \xedmpar'}
# 11089-190 11089190
# {'bairro': u'Santa Maria',
#  'cep': u'11089-190',
#  'localidade': u'Santos/SP',
#  'logradouro': u'Rua Tenente Am\xe9rico Moretti'}
# 09791-080 09791080
# {'bairro': u'Ferraz\xf3polis',
#  'cep': u'09791-080',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Ara\xfajo Viana (Jd Silvina)'}
# 03020-000 03020000
# {'bairro': u'Catumbi',
#  'cep': u'03020-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Marcos Arruda'}
# 09710-192 09710192
# {'bairro': u'Centro',
#  'cep': u'09710-192',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Marechal Deodoro - de 1863 a 2351 - lado \xedmpar'}
# 04246-001 04246001
# {'bairro': u'Vila Moinho Velho',
#  'cep': u'04246-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Via Anchieta - de 972 a 1450 - lado par'}
# 09891-001 09891001
# {'bairro': u'Planalto',
#  'cep': u'09891-001',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Piraporinha - de 421/422 a 889/890'}
# 05539-080 05539080
# {'bairro': u'Jardim Adhemar de Barros',
#  'cep': u'05539-080',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Jos\xe9 \xc1lvares Maciel'}
# 05539-010 05539010
# {'bairro': u'Conjunto Residencial Butant\xe3',
#  'cep': u'05539-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Paulo \xc2ngelo Lanzarini'}
# 05508-020 05508020
# {'bairro': u'Butant\xe3',
#  'cep': u'05508-020',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Professor L\xfacio Martins Rodrigues'}
# 02113-012 02113012
# {'bairro': u'Vila Maria',
#  'cep': u'02113-012',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Guilherme Cotching - de 842 a 1600 - lado par'}
# 05077010 05077010
# {'bairro': u'Lapa',
#  'cep': u'05077-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Ernesto Igel'}
# 09850-900 09850900
# {'bairro': u'Independ\xeancia',
#  'cep': u'09850-900',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Humberto Alencar Castelo Branco, 4110  Condom\xednio Vila Rica'}
# 09830-285 09830285
# {'bairro': u'Rio Grande',
#  'cep': u'09830-285',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Ant\xf4nio Caputo'}
# 09626-130 09626130
# {'bairro': u'Rudge Ramos',
#  'cep': u'09626-130',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Piagentini'}
# 09810-290 09810290
# {'bairro': u'Assun\xe7\xe3o',
#  'cep': u'09810-290',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua dos Cravos'}
# 09850-480 09850480
# {'bairro': u'Alves Dias',
#  'cep': u'09850-480',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Estrada da Cooperativa'}
# 09890-460 09890460
# {'bairro': u'Planalto',
#  'cep': u'09890-460',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Al\xedpio Correa Neto (Vl J\xfapiter)'}
# 09655-000 09655000
# {'bairro': u'Tabo\xe3o',
#  'cep': u'09655-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida do Tabo\xe3o - at\xe9 3011/3012'}
# 09835-001 09835001
# {'bairro': u'Curucutu',
#  'cep': u'09835-001',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Camorin'}
# 09725-570 09725570
# {'bairro': u'Jardim Olavo Bilac',
#  'cep': u'09725-570',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Olavo Bilac'}
# 09210-580 09210580
# {'bairro': u'Jardim Alzira Franco',
#  'cep': u'09290-340',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Avenida dos Estados'}
# 07012-040 07012040
# {'bairro': u'Centro',
#  'cep': u'07012-040',
#  'localidade': u'Guarulhos/SP',
#  'logradouro': u'Rua Bar\xe3o de Mau\xe1'}
# 06150000 06150000
# {'bairro': u'Veloso',
#  'cep': u'06150-000',
#  'localidade': u'Osasco/SP',
#  'logradouro': u'Avenida Sarah Veloso'}
# 09980-720 09980720
# {'bairro': u'Serraria',
#  'cep': u'09980-720',
#  'localidade': u'Diadema/SP',
#  'logradouro': u'Travessa Jurupis'}
# 09911-160 09911160
# {'bairro': u'Centro',
#  'cep': u'09911-160',
#  'localidade': u'Diadema/SP',
#  'logradouro': u'Avenida Ant\xf4nio Piranga - at\xe9 1699/1700'}
# 03074-000 03074000
# {'bairro': u'Vila Moreira',
#  'cep': u'03074-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Condessa Elisabeth de Robiano'}
# 09060-650 09060650
# {'bairro': u'Vila Pr\xedncipe de Gales',
#  'cep': u'09060-650',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Avenida Pr\xedncipe de Gales'}
# 03345-000 03345000
# {'bairro': u'Vila Regente Feij\xf3',
#  'cep': u'03345-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Sapopemba - at\xe9 3740 - lado par'}
# 02072-002 02072002
# {'bairro': u'Vila Paiva',
#  'cep': u'02072-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Concei\xe7\xe3o - de 1575/1576 a 2399/2400'}
# 03033-030 03033030
# {'bairro': u'Canind\xe9',
#  'cep': u'03033-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Afonso Arinos'}
# 01107-000 01107000
# {'bairro': u'Bom Retiro',
#  'cep': u'01107-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida do Estado - at\xe9 2599 - lado \xedmpar'}
# 02111-001 02111001
# {'bairro': u'Vila Maria',
#  'cep': u'02111-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Severa - de 601/602 ao fim'}
# 02111-001 02111001
# {'bairro': u'Vila Maria',
#  'cep': u'02111-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Severa - de 601/602 ao fim'}
# 02128-010 02128010
# {'bairro': u'Vila Maria Alta',
#  'cep': u'02128-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Sim\xe3o Borges'}
# 03623-010 03623010
# {'bairro': u'Vila Granada',
#  'cep': u'03623-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Wolstein'}
# 13214-900 13214900
# {'bairro': u'Jardim Bot\xe2nico',
#  'cep': u'13214-900',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Avenida da Liberdade, s/n  Pa\xe7o Municipal  Nova Jundia\xed'}
# 02221-001 02221001
# {'bairro': u'Jardim Brasil (Zona Norte)',
#  'cep': u'02221-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Jardim Jap\xe3o - de 1103/1104 ao fim'}
# 02072-000 02072000
# {'bairro': u'Carandiru',
#  'cep': u'02072-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Concei\xe7\xe3o - at\xe9 909/910'}
# 03586-000 03586000
# {'bairro': u'Cidade L\xedder',
#  'cep': u'03586-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida L\xedder - at\xe9 1199/1200'}
# 03047-000 03047000
# {'bairro': u'Br\xe1s',
#  'cep': u'03047-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua 21 de Abril'}
# 03026-001 03026001
# {'bairro': u'Pari',
#  'cep': u'03026-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Silva Teles - lado \xedmpar'}
# 13202-610 13202610
# {'bairro': u'Vila Arens II',
#  'cep': u'13202-610',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Avenida S\xe3o Paulo'}
# 03028-040 03028040
# {'bairro': u'Pari',
#  'cep': u'03028-040',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Siqueira Afonso'}
# 05092-000 05092000
# {'bairro': u'Vila Anast\xe1cio',
#  'cep': u'05092-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Bartolomeu Paes'}
# 02232-000 02232000
# {'bairro': u'Parque Edu Chaves',
#  'cep': u'02232-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Major Baracca'}
# 02134-002 02134002
# {'bairro': u'Vila Maria Alta',
#  'cep': u'02134-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Padre Sab\xf3ia de Medeiros - de 1363/1364 ao fim'}
# 04298-060 04298060
# {'bairro': u'Vila Vermelha',
#  'cep': u'04298-060',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Alberto I'}
# 05755-090 05755090
# {'bairro': u'Jardim Umarizal',
#  'cep': u'05755-090',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Anac\xe9'}
# 02113-015 02113015
# {'bairro': u'Vila Maria',
#  'cep': u'02113-015',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Guilherme Cotching - de 1349 a 1629 - lado \xedmpar'}
# 02136-000 02136000
# {'bairro': u'Vila Maria Alta',
#  'cep': u'02136-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Doutor Benedito Estevam dos Santos'}
# 03022-070 03022070
# {'bairro': u'Catumbi',
#  'cep': u'03022-070',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Bernardo Sai\xe3o'}
# 02112-002 02112002
# {'bairro': u'Vila Maria',
#  'cep': u'02112-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Guaran\xe9sia - de 1001/1002 ao fim'}
# 01107-000 01107000
# {'bairro': u'Bom Retiro',
#  'cep': u'01107-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida do Estado - at\xe9 2599 - lado \xedmpar'}
# 03024-000 03024000
# {'bairro': u'Catumbi',
#  'cep': u'03024-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Cachoeira'}
# 03585-000 03585000
# {'bairro': u'Jardim Bras\xedlia (Zona Leste)',
#  'cep': u'03585-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Gameleira Branca'}
# 03018-020 03018020
# {'bairro': u'Br\xe1s',
#  'cep': u'03018-020',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua God\xf3i Preto'}
# 02065-000 02065000
# {'bairro': u'Vila Guilherme',
#  'cep': u'02065-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Joaquina Ramalho - at\xe9 1238 - lado par'}
# 03032-000 03032000
# {'bairro': u'Canind\xe9',
#  'cep': u'03032-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Vautier'}
# 02054-100 02054100
# {'bairro': u'Vila Guilherme',
#  'cep': u'02054-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Jo\xe3o Ventura Batista'}
# 03027-020 03027020
# {'bairro': u'Br\xe1s',
#  'cep': u'03027-020',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Doutor Virg\xedlio do Nascimento'}
# 03018-010 03018010
# {'bairro': u'Br\xe1s',
#  'cep': u'03018-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Coronel Em\xeddio Piedade'}
# 02052-001 02052001
# {'bairro': u'Vila Guilherme',
#  'cep': u'02052-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Doze de Setembro - de 831/832 ao fim'}
# 02052-000 02052000
# {'bairro': u'Vila Guilherme',
#  'cep': u'02052-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Doze de Setembro - at\xe9 829/830'}
# 02067-000 02067000
# {'bairro': u'Carandiru',
#  'cep': u'02067-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Chico Pontes - at\xe9 519/520'}
# 03029-070 03029070
# {'bairro': u'Canind\xe9',
#  'cep': u'03029-070',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Pascoal Malatesta'}
# 02074-000 02074000
# {'bairro': u'Vila Paiva',
#  'cep': u'02074-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua do Imperador - at\xe9 639/640'}
# 13209-355 13209355
# {'bairro': u'Vila das Hort\xeancias',
#  'cep': u'13209-355',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua do Retiro - de 1746/1747 ao fim'}
# 01121-000 01121000
# {'bairro': u'Bom Retiro',
#  'cep': u'01121-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Prates'}
# 01125-001 01125001
# {'bairro': u'Bom Retiro',
#  'cep': u'01125-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua da Gra\xe7a - de 1 ao fim - lado \xedmpar'}
# 01104-001 01104001
# {'bairro': u'Luz',
#  'cep': u'01104-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua S\xe3o Caetano - lado \xedmpar'}
# 03004-000 03004000
# {'bairro': u'Br\xe1s',
#  'cep': u'03004-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua do Gas\xf4metro - lado par'}
# 02115-000 02115000
# {'bairro': u'Vila Maria Baixa',
#  'cep': u'02115-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Amamba\xed - at\xe9 659/660'}
# 03007-060 03007060
# {'bairro': u'Br\xe1s',
#  'cep': u'03007-060',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Mendes Caldeira'}
# 03024-010 03024010
# {'bairro': u'Catumbi',
#  'cep': u'03024-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Capit\xe3o-mor Passos'}
# 03035-090 03035090
# {'bairro': u'Pari',
#  'cep': u'03035-090',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Agua\xe7a\xed'}
# 03019-020 03019020
# {'bairro': u'Br\xe1s',
#  'cep': u'03019-020',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Jos\xe9 Kauer'}
# 02232-050 02232050
# {'bairro': u'Parque Edu Chaves',
#  'cep': u'02232-050',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Capit\xe3o Busse'}
# 13209-355 13209355
# {'bairro': u'Vila das Hort\xeancias',
#  'cep': u'13209-355',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua do Retiro - de 1746/1747 ao fim'}
# 02219-000 02219000
# {'bairro': u'Vila Medeiros',
#  'cep': u'02219-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Nossa Senhora do Loreto - at\xe9 911/912'}
# 09830-100 09830100
# {'bairro': u'Rio Grande',
#  'cep': u'09830-100',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Rio Acima'}
# 13214-717 13214717
# {'bairro': u'Parque Cecap',
#  'cep': u'13214-717',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua Alceu de Toledo Pontes'}
# 13206-475 13206475
# {'bairro': u'Vila Garcia',
#  'cep': u'13206-475',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua Cica - de 851/852 a 1913/1914'}
# 04260-000 04260000
# {'bairro': u'Ipiranga',
#  'cep': u'04260-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Doutor Ricardo Jafet - at\xe9 2000 - lado par'}
# 12246-130 12246130
# {'bairro': u'Parque Residencial Aquarius',
#  'cep': u'12246-130',
#  'localidade': u'S\xe3o Jos\xe9 dos Campos/SP',
#  'logradouro': u'Rua Ruivo'}
# 11060-003 11060003
# {'bairro': u'Gonzaga',
#  'cep': u'11060-003',
#  'localidade': u'Santos/SP',
#  'logradouro': u'Avenida Ana Costa - de 343 ao fim - lado \xedmpar'}
# 13219-001 13219001
# {'bairro': u'Vila Santana II',
#  'cep': u'13219-001',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Avenida Ant\xf4nio Frederico Ozanan - de 1001/1002 a 1999/2000'}
# 09540-280 09540280
# {'bairro': u'Santa Paula',
#  'cep': u'09540-280',
#  'localidade': u'S\xe3o Caetano do Sul/SP',
#  'logradouro': u'Rua Osvaldo Cruz - de 821/822 ao fim'}
# 02110-000 02110000
# {'bairro': u'Vila Maria Baixa',
#  'cep': u'02110-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Nadir Dias de Figueiredo'}
# 05513-100 05513100
# {'bairro': u'Butant\xe3',
#  'cep': u'05513-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Professor Francisco Morato - de 1001 a 1599 - lado \xedmpar'}
# 03172-080 03172080
# {'bairro': u'Belenzinho',
#  'cep': u'03172-080',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Largo Ubirajara'}
# 13214-719 13214719
# {'bairro': u'Parque Cecap',
#  'cep': u'13214-719',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua Ant\xf4nio Graciadio'}
# 02071-012 02071012
# {'bairro': u'Vila Guilherme',
#  'cep': u'02071-012',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Maria C\xe2ndida - de 0973 a 1651 - lado \xedmpar'}
# CEP 03711-000 Nao existe
# 02065-010 02065010
# {'bairro': u'Vila Guilherme',
#  'cep': u'02065-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Joaquina Ramalho - at\xe9 1239 - lado \xedmpar'}
# 03022-030 03022030
# {'bairro': u'Alto do Pari',
#  'cep': u'03022-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Ferreira de Oliveira'}
# 09920-650 09920650
# {'bairro': u'Centro',
#  'cep': u'09920-650',
#  'localidade': u'Diadema/SP',
#  'logradouro': u'Rua Orense (Prq Jaboticabeiras)'}
# 02701-000 02701000
# {'bairro': u'Jardim das Gra\xe7as',
#  'cep': u'02701-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Otaviano Alves de Lima'}
# 01514-000 01514000
# {'bairro': u'Liberdade',
#  'cep': u'01514-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua do Glic\xe9rio - at\xe9 405/406'}
# 12233-001 12233001
# {'bairro': u'Bosque dos Eucaliptos',
#  'cep': u'12233-001',
#  'localidade': u'S\xe3o Jos\xe9 dos Campos/SP',
#  'logradouro': u'Avenida Andr\xf4meda - de 2532 ao fim - lado par'}
# 04134-030 04134030
# {'bairro': u'Vila Gumercindo',
#  'cep': u'04134-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Dom Manuel da Ressurrei\xe7\xe3o'}
# 02511-000 02511000
# {'bairro': u'Casa Verde',
#  'cep': u'02511-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Braz Leme - at\xe9 1799/1800'}
# 03331-000 03331000
# {'bairro': u'Quarta Parada',
#  'cep': u'03331-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida \xc1lvaro Ramos - de 603 a 1071 - lado \xedmpar'}
# 09520-400 09520400
# {'bairro': u'Funda\xe7\xe3o',
#  'cep': u'09520-400',
#  'localidade': u'S\xe3o Caetano do Sul/SP',
#  'logradouro': u'Avenida do Estado - at\xe9 1388 - lado par'}
# 09220-570 09220570
# {'bairro': u'Vila Metal\xfargica',
#  'cep': u'09220-570',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Avenida dos Estados'}
# 05038-000 05038000
# {'bairro': u'\xc1gua Branca',
#  'cep': u'05038-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Ermano Marchetti - at\xe9 871/872'}
# 01221-000 01221000
# {'bairro': u'Vila Buarque',
#  'cep': u'01221-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Amaral Gurgel - lado par'}
# 13211-782 13211782
# {'bairro': u'Jardim Guanabara',
#  'cep': u'13211-782',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua Yolande Saraphine Page'}
# 02124-002 02124002
# {'bairro': u'Jardim Jap\xe3o',
#  'cep': u'02124-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida das Cerejeiras - de 1801/1802 ao fim'}
# 09910-720 09910720
# {'bairro': u'Centro',
#  'cep': u'09910-720',
#  'localidade': u'Diadema/SP',
#  'logradouro': u'Rua Manoel da N\xf3brega (Prq S Setembro)'}
# 06833-300 06833300
# {'bairro': u'Parque Francisco Rizzo',
#  'cep': u'06803-285',
#  'localidade': u'Embu das Artes/SP',
#  'logradouro': u'Rua Jos\xe9 Semi\xe3o Rodrigues Agostinho - at\xe9 223/224'}
# 09820-000 09820000
# {'bairro': u'Demarchi',
#  'cep': u'09820-000',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Avenida Maria Servidei Demarchi'}
# 05346-000 05346000
# {'bairro': u'Jaguar\xe9',
#  'cep': u'05346-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Jaguar\xe9'}
# 13218-233 13218233
# {'bairro': u'Jardim Pacaembu',
#  'cep': u'13218-233',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua R\xfabens Pires'}
# 05319-000 05319000
# {'bairro': u'Vila Hamburguesa',
#  'cep': u'05319-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Queiroz Filho'}
# 03125-040 03125040
# {'bairro': u'Parque da Mooca',
#  'cep': u'03125-040',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Domingos da Fonseca'}
# 08247-001 08247001
# {'bairro': u'Parada XV de Novembro',
#  'cep': u'08247-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Dam\xe1sio Pinto - de 674/675 a 1089/1090'}
# 02313-000 02313000
# {'bairro': u'Vila Nova Mazzei',
#  'cep': u'02313-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Manuel Gaya - at\xe9 1273/1274'}
# 02240-000 02240000
# {'bairro': u'Parada Inglesa',
#  'cep': u'02240-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Doutor Ant\xf4nio Maria Laet'}
# 11430-000 11430000
# {'bairro': u'Vila Santo Ant\xf4nio',
#  'cep': u'11430-000',
#  'localidade': u'Guaruj\xe1/SP',
#  'logradouro': u'Avenida Adhemar de Barros - at\xe9 867/868'}
# 03342-000 03342000
# {'bairro': u'Vila Regente Feij\xf3',
#  'cep': u'03342-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Regente Feij\xf3'}
# 06655300 06655300
# {'bairro': u'Jardim Briquet',
#  'cep': u'06655-300',
#  'localidade': u'Itapevi/SP',
#  'logradouro': u'Rua B\xe9rgamo'}
# 03295-100 03295100
# {'bairro': u'Vila Ema',
#  'cep': u'03295-100',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Professor Luiz Ign\xe1cio Anhaia Mello - de 6003 a 9401 - lado \xedmpar'}
# 04626-000 04626000
# {'bairro': u'Santo Amaro',
#  'cep': u'04626-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Washington Lu\xeds - de 2952 a 5572 - lado par'}
# 04089-002 04089002
# {'bairro': u'Indian\xf3polis',
#  'cep': u'04089-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Alameda dos Maracatins - de 1002 a 1160 - lado par'}
# 13208-200 13208200
# {'bairro': u'Anhangaba\xfa',
#  'cep': u'13208-200',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua Engenheiro Roberto Mange'}
# 01537-001 01537001
# {'bairro': u'Cambuci',
#  'cep': u'01537-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Lins de Vasconcelos - de 1149 a 2159 - lado \xedmpar'}
# 02072-002 02072002
# {'bairro': u'Vila Paiva',
#  'cep': u'02072-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Concei\xe7\xe3o - de 1575/1576 a 2399/2400'}
# 02265-002 02265002
# {'bairro': u'Tucuruvi',
#  'cep': u'02265-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Guapira - de 1051/1052 ao fim'}
# 04662-002 04662002
# {'bairro': u'Santo Amaro',
#  'cep': u'04662-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Washington Lu\xeds - de 1001/1002 a 2689/2690'}
# 04762-001 04762001
# {'bairro': u'Vila Socorro',
#  'cep': u'04762-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Guarapiranga - at\xe9 1100 - lado par'}
# 04230-040 04230040
# {'bairro': u'Cidade Nova Heli\xf3polis',
#  'cep': u'04230-040',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Almirante Delamare - lado \xedmpar'}
# 09330-150 09330150
# {'bairro': u'Jardim Itapeva',
#  'cep': u'09330-150',
#  'localidade': u'Mau\xe1/SP',
#  'logradouro': u'Avenida Bar\xe3o de Mau\xe1 - de 4101/4102 a 4999/5000'}
# 02350-001 02350001
# {'bairro': u'Vila Albertina',
#  'cep': u'02350-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Maria Am\xe1lia Lopes Azevedo - de 580 a 1100 - lado par'}
# 02415-000 02415000
# {'bairro': u'Parque Mandaqui',
#  'cep': u'02415-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Santa In\xeas - at\xe9 699/700'}
# 03533-002 03533002
# {'bairro': u'Vila Talarico',
#  'cep': u'03533-002',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Waldemar Carlos Pereira - de 0966 ao fim - lado par'}
# 03930-310 03930310
# {'bairro': u'Jardim Aricanduva',
#  'cep': u'03930-310',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Rio das Pedras - de 3057 ao fim - lado \xedmpar'}
# 03106-010 03106010
# {'bairro': u'Mooca',
#  'cep': u'03106-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Dona Ana Neri - at\xe9 499/500'}
# 01537-001 01537001
# {'bairro': u'Cambuci',
#  'cep': u'01537-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Lins de Vasconcelos - de 1149 a 2159 - lado \xedmpar'}
# 01309-000 01309000
# {'bairro': u'Consola\xe7\xe3o',
#  'cep': u'01309-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Lu\xeds Coelho - lado par'}
# 05521-000 05521000
# {'bairro': u'Vila S\xf4nia',
#  'cep': u'05521-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Professor Francisco Morato - de 3179 a 3679 - lado \xedmpar'}
# 06296-190 06296190
# {'bairro': u'Rem\xe9dios',
#  'cep': u'06296-190',
#  'localidade': u'Osasco/SP',
#  'logradouro': u'Avenida Nossa Senhora dos Rem\xe9dios'}
# 08330510 08330510
# {'bairro': u'Cidade Sat\xe9lite Santa B\xe1rbara',
#  'cep': u'08330-510',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Dione'}
# 13207-070 13207070
# {'bairro': u'Vila Vianelo',
#  'cep': u'13207-070',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua Vinte e Tr\xeas de Maio'}
# 04662-901 04662901
# {'bairro': u'Santo Amaro',
#  'cep': u'04662-901',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Washington Lu\xeds, 1527  Condom\xednio Ch\xe1cara das Flores'}
# 02031-000 02031000
# {'bairro': u'Canind\xe9',
#  'cep': u'02031-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Cruzeiro do Sul - de 1301 a 2667 - lado \xedmpar'}
# 03057-010 03057010
# {'bairro': u'Belenzinho',
#  'cep': u'03057-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Bel\xe9m'}
# 13202-451 13202451
# {'bairro': u'Vila Vianelo',
#  'cep': u'13202-451',
#  'localidade': u'Jundia\xed/SP',
#  'logradouro': u'Rua Professor Jo\xe3o Luiz de Campos'}
# 05508-090 05508090
# {'bairro': u'Butant\xe3',
#  'cep': u'05508-090',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua do Mat\xe3o'}
# 05060060 05060060
# {'bairro': u'Alto da Lapa',
#  'cep': u'05060-060',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Travessa Louren\xe7o Pellegati'}
# 05508-120 05508120
# {'bairro': u'Butant\xe3',
#  'cep': u'05508-120',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Pra\xe7a do Oceanogr\xe1fico'}
# 09090-450 09090450
# {'bairro': u'Vila Guiomar',
#  'cep': u'09090-450',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Rua Ubatuba'}
# 09230-490 09230490
# {'bairro': u'Vila Camil\xf3polis',
#  'cep': u'09230-490',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Rua Rossini'}
# 06767-220 06767220
# {'bairro': u'Parque Pinheiros',
#  'cep': u'06767-220',
#  'localidade': u'Tabo\xe3o da Serra/SP',
#  'logradouro': u'Avenida Paulo Ayres'}
# 06767-230 06767230
# {'bairro': u'Parque Pinheiros',
#  'cep': u'06767-230',
#  'localidade': u'Tabo\xe3o da Serra/SP',
#  'logradouro': u'Rua M\xe1rio Latorre'}
# 06786-070 06786070
# {'bairro': u'Jardim S\xe3o Judas Tadeu',
#  'cep': u'06786-070',
#  'localidade': u'Tabo\xe3o da Serra/SP',
#  'logradouro': u'Rua Paulo Augusto de Andrade'}
# 13295-000 13295000
# {'bairro': u'',
#  'cep': u'13295-000',
#  'localidade': u'Itupeva/SP',
#  'logradouro': u''}
# 01402-001 01402001
# {'bairro': u'Jardim Paulista',
#  'cep': u'01402-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Brigadeiro Lu\xeds Ant\xf4nio - de 3200 a 4098 - lado par'}
# 01246-904 01246904
# {'bairro': u'Pacaembu',
#  'cep': u'01246-904',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Doutor Arnaldo, 715  Faculdade de Sa\xfade P\xfablica'}
# 04551-060 04551060
# {'bairro': u'Vila Ol\xedmpia',
#  'cep': u'04551-060',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Funchal'}
# 04842-150 04842150
# {'bairro': u'Jardim Castro Alves',
#  'cep': u'04842-150',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Jo\xe3o Paulo Barreto'}
# 09890 070 09890070
# {'bairro': u'Planalto',
#  'cep': u'09890-070',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Lemos Torres (Jd Gagliardi)'}
# 06703-440 06703440
# {'bairro': u'Jardim Nova Coimbra',
#  'cep': u'06703-440',
#  'localidade': u'Cotia/SP',
#  'logradouro': u'Rua Pintassilgo'}
# 07180041 07180041
# {'bairro': u'Jardim Cumbica',
#  'cep': u'07180-041',
#  'localidade': u'Guarulhos/SP',
#  'logradouro': u'Viela In\xfabia Paulista'}
# 09890 070 09890070
# {'bairro': u'Planalto',
#  'cep': u'09890-070',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Lemos Torres (Jd Gagliardi)'}
# 13225-070 13225070
# {'bairro': u'Vila Tupi',
#  'cep': u'13225-070',
#  'localidade': u'V\xe1rzea Paulista/SP',
#  'logradouro': u'Rua Turiassu'}
# 09541-220 09541220
# {'bairro': u'Santa Paula',
#  'cep': u'09541-220',
#  'localidade': u'S\xe3o Caetano do Sul/SP',
#  'logradouro': u'Rua Tiradentes'}
# 04191140 04191140
# {'bairro': u'Vila Caraguat\xe1',
#  'cep': u'04191-140',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Jo\xe3o Jos\xe9 da Silva'}
# 11060-002 11060002
# {'bairro': u'Gonzaga',
#  'cep': u'11060-002',
#  'localidade': u'Santos/SP',
#  'logradouro': u'Avenida Ana Costa - de 342 ao fim - lado par'}
# 06765-020 06765020
# {'bairro': u'Jardim Helena',
#  'cep': u'06765-020',
#  'localidade': u'Tabo\xe3o da Serra/SP',
#  'logradouro': u'Rua Geraldo de Ara\xfajo Santos'}
# 09623-030 09623030
# {'bairro': u'Rudge Ramos',
#  'cep': u'09623-030',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Martini'}
# 04211-040 04211040
# {'bairro': u'Ipiranga',
#  'cep': u'04211-040',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Cisplatina'}
# 08441-000 08441000
# {'bairro': u'Jardim Robru',
#  'cep': u'08441-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Doutor Jos\xe9 Gravonski - at\xe9 588/589'}
# 04551-060 04551060
# {'bairro': u'Vila Ol\xedmpia',
#  'cep': u'04551-060',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Funchal'}
# 05685-010 05685010
# {'bairro': u'Real Parque',
#  'cep': u'05685-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Visconde de Nacar'}
# 01321-001 01321001
# {'bairro': u'Bela Vista',
#  'cep': u'01321-001',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Martiniano de Carvalho - lado \xedmpar'}
# 07040-010 07040010
# {'bairro': u'Vila Augusta',
#  'cep': u'07040-010',
#  'localidade': u'Guarulhos/SP',
#  'logradouro': u'Rua Francisco Antunes'}
# 03632-010 03632010
# {'bairro': u'Penha de Fran\xe7a',
#  'cep': u'03632-010',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Pra\xe7a Nossa Senhora da Penha'}
# 09571-010 09571010
# {'bairro': u'Osvaldo Cruz',
#  'cep': u'09571-010',
#  'localidade': u'S\xe3o Caetano do Sul/SP',
#  'logradouro': u'Rua Visconde de Inha\xfama - at\xe9 631 - lado \xedmpar'}
# 08715-030 08715030
# {'bairro': u'Centro',
#  'cep': u'08715-030',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Rua S\xe3o Jo\xe3o - de 151/152 ao fim'}
# 07834-950 07834950
# {'bairro': u'Glebas',
#  'cep': u'07834-950',
#  'localidade': u'Franco da Rocha/SP',
#  'logradouro': u'Rodovia Edgar M\xe1ximo Zamboto, Km 44,5  Penitenci\xe1ria Nilton Silva'}
# 07859-340 07859340
# {'bairro': u'Pouso Alegre',
#  'cep': u'07859-340',
#  'localidade': u'Franco da Rocha/SP',
#  'logradouro': u'Estrada do Governo - de 76/77 a 884/885'}
# 09960-050 09960050
# {'bairro': u'Vila Nogueira',
#  'cep': u'09960-050',
#  'localidade': u'Diadema/SP',
#  'logradouro': u'Rua Padre Ant\xf4nio Tomaz (Jd S Elizabeth)'}
# 09710-180 09710180
# {'bairro': u'Centro',
#  'cep': u'09710-180',
#  'localidade': u'S\xe3o Bernardo do Campo/SP',
#  'logradouro': u'Rua Doutor Flaquer'}
# 08430540 08430540
# {'bairro': u'Jardim Etelvina',
#  'cep': u'08430-540',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Jo\xe3o Gomes de Farias'}
# 08820-520 08820520
# {'bairro': u'N\xfacleo Industrial Vereador Alcides Celestino Filho',
#  'cep': u'08820-520',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Avenida Em\xedlia Mossri'}
# 03227-110 03227110
# {'bairro': u'Jardim Avelino',
#  'cep': u'03227-110',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Mendon\xe7a Corte Real'}
# 09570-420 09570420
# {'bairro': u'S\xe3o Jos\xe9',
#  'cep': u'09570-420',
#  'localidade': u'S\xe3o Caetano do Sul/SP',
#  'logradouro': u'Rua \xc2ngelo Aparecido Radim'}
# 08773-395 08773395
# {'bairro': u'Vila Partenio',
#  'cep': u'08773-395',
#  'localidade': u'Mogi das Cruzes/SP',
#  'logradouro': u'Rua Antenor Leite da Cunha'}
# 09090-300 09090300
# {'bairro': u'Vila Alpina',
#  'cep': u'09090-300',
#  'localidade': u'Santo Andr\xe9/SP',
#  'logradouro': u'Largo S\xe3o Francisco'}
# 03065-000 03065000
# {'bairro': u'Tatuap\xe9',
#  'cep': u'03065-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Filipe Camar\xe3o'}
# 02142-030 02142030
# {'bairro': u'Jardim Jap\xe3o',
#  'cep': u'02142-030',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Soldado Jos\xe9 Higaskino'}
# 05019-000 05019000
# {'bairro': u'Perdizes',
#  'cep': u'05019-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Diana'}
# 02720-200 02720200
# {'bairro': u'Lim\xe3o',
#  'cep': u'02720-200',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Deputado Em\xedlio Carlos - de 1752 ao fim - lado par'}
# 02402-300 02402300
# {'bairro': u'Santana',
#  'cep': u'02402-300',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Volunt\xe1rios da P\xe1tria - de 3200 a 3598 - lado par'}
# 02965-140 02965140
# {'bairro': u'Jardim Mariliza',
#  'cep': u'02965-140',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Rua Padre Feliciano Domingues'}
# 08090-000 08090000
# {'bairro': u'Parque Paulistano',
#  'cep': u'08090-000',
#  'localidade': u'S\xe3o Paulo/SP',
#  'logradouro': u'Avenida Doutor Jos\xe9 Artur Nova'}
